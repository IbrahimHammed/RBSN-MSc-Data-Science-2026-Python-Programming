# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimHammed/RBSN-MSc-Data-Science-2026-Python-Programming/blob/main/RBSN_DSAPR26_Pandas_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import needed library
import pandas as pd

# %%
# Set file location
fileLocation = "https://github.com/IbrahimHammed/RBSN-MSc-Data-Science-2026-Python-Proramming/blob/main/world-population-by-country-2020.json?raw=true"

# %%
# Connect to and load data from a file
# Example: .JSON file
df1 = pd.read_json(fileLocation)

# %%
# Preview the top 5 rows of the loaded data
df1.head()
# Out:
#    position        country     population yearly_change  net_change  \
# 0         1          China  1,439,323,776        0.39 %   5,540,090
# 1         2          India  1,380,004,385        0.99 %  13,586,631
# 2         3  United States    331,002,651        0.59 %   1,937,734
# 3         4      Indonesia    273,523,615        1.07 %   2,898,047
# 4         5       Pakistan    220,892,340        2.00 %   4,327,022
#
#   density_per_square_km land_are_in_square_km migrants_net fertility_rate  \
# 0                   153             9,388,211     -348,399            1.7
# 1                   464             2,973,190     -532,687            2.2
# 2                    36             9,147,420      954,806            1.8
# 3                   151             1,811,570      -98,955            2.3
# 4                   287               770,880     -233,379            3.6
#
#   median_age urban_population world_share
# 0         38             61 %     18.47 %
# ...

# %%
# Preview the last 5 rows of the loaded data
df1.tail()
# Out:
#      position           country population yearly_change net_change  \
# 230       231        Montserrat      4,992        0.06 %          3
# 231       232  Falkland Islands      3,480        3.05 %        103
# 232       233              Niue      1,626        0.68 %         11
# 233       234           Tokelau      1,357        1.27 %         17
# 234       235          Holy See        801        0.25 %          2
#
#     density_per_square_km land_are_in_square_km migrants_net fertility_rate  \
# 230                    50                   100                        N.A.
# 231                     0                12,170                        N.A.
# 232                     6                   260                        N.A.
# 233                   136                    10                        N.A.
# 234                 2,003                     0                        N.A.
#
#     median_age urban_population world_share
# 230       N.A.             10 %      0.00 %
# ...

# %%
# Preview the top n rows of the loaded data
n = 3
df1.head(n)
# Out:
#    position        country     population yearly_change  net_change  \
# 0         1          China  1,439,323,776        0.39 %   5,540,090
# 1         2          India  1,380,004,385        0.99 %  13,586,631
# 2         3  United States    331,002,651        0.59 %   1,937,734
#
#   density_per_square_km land_are_in_square_km migrants_net fertility_rate  \
# 0                   153             9,388,211     -348,399            1.7
# 1                   464             2,973,190     -532,687            2.2
# 2                    36             9,147,420      954,806            1.8
#
#   median_age urban_population world_share
# 0         38             61 %     18.47 %
# 1         28             35 %     17.70 %
# 2         38             83 %      4.25 %

# %%
# Preview the last n rows of the loaded data
n = 3
df1.tail(n)
# Out:
#      position   country population yearly_change net_change  \
# 232       233      Niue      1,626        0.68 %         11
# 233       234   Tokelau      1,357        1.27 %         17
# 234       235  Holy See        801        0.25 %          2
#
#     density_per_square_km land_are_in_square_km migrants_net fertility_rate  \
# 232                     6                   260                        N.A.
# 233                   136                    10                        N.A.
# 234                 2,003                     0                        N.A.
#
#     median_age urban_population world_share
# 232       N.A.             46 %      0.00 %
# 233       N.A.              0 %      0.00 %
# 234       N.A.             N.A.      0.00 %

# %%
# Preview a sample row from the loaded data
df1.sample()
# Out:
#      position       country population yearly_change net_change  \
# 228       229  Saint Helena      6,077        0.30 %         18
#
#     density_per_square_km land_are_in_square_km migrants_net fertility_rate  \
# 228                    16                   390                        N.A.
#
#     median_age urban_population world_share
# 228       N.A.             27 %      0.00 %

# %%
# Preview sample n rows of the loaded data
n = 7
df1.sample(n)
# Out:
#      position                   country  population yearly_change net_change  \
# 201       202               Isle of Man      85,033        0.53 %        449
# 191       192                   Curaçao     164,093        0.41 %        669
# 93         94                   Hungary   9,660,351       -0.25 %    -24,328
# 26         27                     Kenya  53,771,296        2.28 %  1,197,323
# 227       228          Saint Barthelemy       9,877        0.30 %         30
# 85         86  Czech Republic (Czechia)  10,708,981        0.18 %     19,772
# 178       179                Martinique     375,265       -0.08 %       -289
#
#     density_per_square_km land_are_in_square_km migrants_net fertility_rate  \
# 201                   149                   570                        N.A.
# 191                   370                   444          515            1.8
# 93                    107                90,530        6,000            1.5
# ...

# %%
# Get the shape of the dataframe (rows and columns)
df1.shape
# Out:
# (235, 12)
